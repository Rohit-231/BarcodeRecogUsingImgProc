# %%
"""importing required package""" 
from pyzbar import pyzbar        #use to decode the qr codes
import cv2                       #use for the manipulation of the image,videos
import matplotlib.pyplot as plt  #use to plot images

# %%
"""For scanning the QR Code in image"""
# load the input image
image = cv2.imread("C:\\Users\\admin\\Desktop\\internship IP\\pic6.jpeg")
# find the barcodes in the image and decode each of the barcodes
plt.imshow(image)
plt.show()
barcodes = pyzbar.decode(image)

# loop over the detected barcodes
for barcode in barcodes:
    # extract the bounding box location of the barcode and draw the
    # bounding box surrounding the barcode on the image
    
#     barcodeType="notfound"
    (x, y, w, h) = barcode.rect
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)
    # the barcode data is a bytes object so if we want to draw it on
    # our output image we need to convert it to a string first
    barcodeData = barcode.data.decode("utf-8")
    barcodeType = barcode.type
    # draw the barcode data and barcode type on the image
    text = "{} ({})".format(barcodeData, barcodeType)
    cv2.putText(image, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX,0.5, (0, 0, 255), 2)
    # print the barcode type and data to the terminal
    print("[INFO] Found {} barcode: {}".format(barcodeType, barcodeData))
    print(x,y,x+w,y+h)
    # show the output image
plt.imshow(image)
plt.show()
# Out:
# [INFO] Found QRCODE barcode: 1@Q8lTYv8sSMW4ewKk05SfigG0GTWbe+o3Domc4IZpbKj5CoO8ZkDaUrWI,4+/LZ0IgbWEntZuEZDf1jL6A9uyBXoET3p1EL4bnGGk=,QvxzDvbToxTSy74ncXHgTw==
# 312 479 463 630

# %%
crop_img = image[y:y+h, x:x+w]
plt.imshow(crop_img)
plt.show()
print("[INFO] Found {} barcode: {}".format(barcodeType, barcodeData))
# Out:
# [INFO] Found QRCODE barcode: 1@Q8lTYv8sSMW4ewKk05SfigG0GTWbe+o3Domc4IZpbKj5CoO8ZkDaUrWI,4+/LZ0IgbWEntZuEZDf1jL6A9uyBXoET3p1EL4bnGGk=,QvxzDvbToxTSy74ncXHgTw==

# %%
"""for scanning QR Code in Recorded Video"""
cap = cv2.VideoCapture('video2.mp4')
while (True):
# Read the frame
    check,img = cap.read()

    barcodes = pyzbar.decode(img)
    for barcode in barcodes:
    # extract the bounding box location of the barcode and draw the
    # bounding box surrounding the barcode on the image
        (x, y, w, h) = barcode.rect
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)
    # the barcode data is a bytes object so if we want to draw it on
    # our output image we need to convert it to a string first
        barcodeData = barcode.data.decode("utf-8")
        barcodeType = barcode.type
    # draw the barcode data and barcode type on the image
        text = "{} ({})".format(barcodeData, barcodeType)
        cv2.putText(img, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX,
            0.5, (0, 0, 255), 2)

    cv2.imshow('img', img)
    crop_img = img[y:y+h, x:x+w]

    # Stop if 'q' key is pressed
    k = cv2.waitKey(10) #& 0xff
    if k==ord('q'):
        break
# Release the VideoCapture object
cap.release()
# out.release()
cv2.destroyAllWindows()
print("[INFO] Found {} barcode: {}".format(barcodeType, barcodeData))
# Out:
# [INFO] Found QRCODE barcode: 1@JZ3gmxkQj4tQE8l/o8Qeyy/7pd1PTivO/lJjsisL6mVl9dcpa/bv6QVc,wZSU03WLkLDDj+zRPmL+HrZUIL2hLdUmNTz8if7wDiA=,xsKz6l1JrM4J5tddfnw70g==

# %%
"""For Scanning QR Code during live videorecording"""
cap = cv2.VideoCapture(0)
while (True):
# Read the frame
    check,img = cap.read()
    barcodes = pyzbar.decode(img)
    for barcode in barcodes:
    # extract the bounding box location of the barcode and draw the
    # bounding box surrounding the barcode on the image
        (x, y, w, h) = barcode.rect
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)
    # the barcode data is a bytes object so if we want to draw it on
    # our output image we need to convert it to a string first
        barcodeData = barcode.data.decode("utf-8")
        barcodeType = barcode.type
    # draw the barcode data and barcode type on the image
        text = "{} ({})".format(barcodeData, barcodeType)
        cv2.putText(img, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX,
            0.5, (0, 0, 255), 2)
    cv2.imshow('img', img)
    # Stop if escape key is pressed
    k = cv2.waitKey(1) #& 0xff
    if k==ord('q'):
        break
# Release the VideoCapture object
cap.release()
# out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-9cfd598babdf> in <module>()
#       4 # Read the frame
#       5     check,img = cap.read()
# ----> 6     barcodes = pyzbar.decode(img)
#       7     for barcode in barcodes:
#       8     # extract the bounding box location of the barcode and draw the
#
# E:\Anaconda\lib\site-packages\pyzbar\pyzbar.py in decode(image, symbols)
#     179         :obj:`list` of :obj:`Decoded`: The values decoded from barcodes.
#     180     """
# --> 181     pixels, width, height = _pixel_data(image)
#     182
#     183     results = []
#
# E:\Anaconda\lib\site-packages\pyzbar\pyzbar.py in _pixel_data(image)
#     145     else:
#     146         # image should be a tuple (pixels, width, height)
# --> 147         pixels, width, height = image
#     148
#     149         # Check dimensions
#
# TypeError: 'NoneType' object is not iterable

# %%
#Files containing QR Codes
with open('datafile.txt') as file:
    qrlist=file.read().splitlines()
print(qrlist)
# Out:
# ['111111', '111112', '111113', '111114', '111115', '111116', '111117', '111118', '111119', '111120']

# %%
"""for checking Authorized or UnAutherized entry"""
cap = cv2.VideoCapture(0)
while (True):
# Read the frame
    check,img = cap.read()
    barcodes = pyzbar.decode(img)
    for barcode in barcodes:
    # extract the bounding box location of the barcode and draw the
    # bounding box surrounding the barcode on the image
        (x, y, w, h) = barcode.rect
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)
    # the barcode data is a bytes object so if we want to draw it on
    # our output image we need to convert it to a string first
        barcodeData = barcode.data.decode("utf-8")
        barcodeType = barcode.type

        if barcodeData in qrlist:
            myOutput = 'Authorized'
            myColor = (0,255,0)
        else:
            myOutput = 'Un-Authorized'
            myColor = (0, 0, 255)
        
    # draw the barcode data and barcode type on the image
        text = "{} ({}) {}".format(myOutput,barcodeType,barcodeData)
        cv2.putText(img, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX,
            0.5, (0, 0, 255), 2)
    cv2.imshow('img', img)
    # Stop if escape key is pressed
    k = cv2.waitKey(1) #& 0xff
    if k==ord('q'):
        break
# Release the VideoCapture object
cap.release()
# out.release()
cv2.destroyAllWindows()
